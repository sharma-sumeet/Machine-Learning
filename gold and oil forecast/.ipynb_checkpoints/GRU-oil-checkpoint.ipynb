# %%
import numpy as np
import pandas as pd
from numpy import array

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU
from sklearn.preprocessing import MinMaxScaler
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#create training data with lookback period
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        dataX.append(dataset[i:(i+look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back =8
data=pd.read_csv('oil_train.csv')
dataset = np.asarray(data[['Price']])
scaler = MinMaxScaler(feature_range=(0, 1))
x_sample = [8,150]
scaler.fit(np.array(x_sample)[:, np.newaxis])
#dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_size = int(len(dataset) * 0.90)
test_size = len(dataset) - train_size
trainx, testy = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
train=scaler.transform(trainx)
test=scaler.transform(testy)
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
print(len(testX),len(testY))
# Out:
# 833 833

# %%
#Model declaration
batch_size = 16
model = Sequential()
model.add(GRU(26,activation='relu',input_shape=(look_back, 1)))
#model.add(Dropout(0.4))
model.add(Dense(5,activation='relu'))
model.add(Dense(1))
opt = Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error', optimizer=opt)

# %%
# %%time
history=model.fit(trainX, trainY, epochs=10, batch_size=batch_size,validation_data=(testX, testY), shuffle=False)
# Out:
# Train on 7559 samples, validate on 833 samples
# Epoch 1/10
# 7559/7559 [==============================] - 18s 2ms/step - loss: 0.0010 - val_loss: 0.0039
# Epoch 2/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 9.1937e-04 - val_loss: 0.0025
# Epoch 3/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 6.7223e-04 - val_loss: 0.0015
# Epoch 4/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 4.7494e-04 - val_loss: 9.0528e-04
# Epoch 5/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 3.4312e-04 - val_loss: 5.9884e-04
# Epoch 6/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 2.6393e-04 - val_loss: 4.3889e-04
# Epoch 7/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 2.1908e-04 - val_loss: 3.5665e-04
# Epoch 8/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 1.9451e-04 - val_loss: 3.1822e-04
# Epoch 9/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 1.8061e-04 - val_loss: 2.9878e-04
# Epoch 10/10
# 7559/7559 [==============================] - 17s 2ms/step - loss: 1.7326e-04 - val_loss: 2.8796e-04
# Wall time: 2min 51s

# %%
trainScore = model.evaluate(trainX, trainY, batch_size=batch_size, verbose=0)
print('Train Score: ', trainScore)
testScore = model.evaluate(testX, testY, batch_size=batch_size, verbose=0)
#print(testX[:252])
print('Test Score: ', testScore)
# Out:
# Train Score:  0.001274492909828815
# Test Score:  0.00028796280478281033

# %%
#plotting history of loss of training data and validation data
plt.plot(history.history['loss'], label='GRU train', color='brown')
plt.plot(history.history['val_loss'], label='GRU test', color='blue')
plt.legend()
plt.show()

# %%
input=test[test_size-look_back:]
r_data=pd.read_csv('oil_july.csv').values
size=r_data.size
predicted_y=[]
for i in range(size):
    #print(input)
    input_lstm=np.reshape(input[i:look_back+i],newshape=1*look_back)
    input_lstm=np.reshape(input_lstm, (1,look_back,1))
    #print(input_lstm)
    y=model.predict(input_lstm,verbose=0)
    #print(y)
    input=np.append(input,y[0])
    y=scaler.inverse_transform(y)
    predicted_y.append(y[0])
    #print(predicted_y)
    #i=i+1

#print(scaler.transform(r_data))

# %%
plt.figure(figsize=(12,5))
plt.plot(r_data, color = 'red', label = 'Real Test Data')
plt.plot(predicted_y, color = 'blue', label = 'Predicted Test Data')
plt.title('one month oil price ahead prediction using GRU')
plt.xlabel('Time')
plt.ylabel('oil price')
plt.legend()
plt.show()

# %%
input=test[test_size-look_back:]
r_data=pd.read_csv('oil_july.csv').values
size=r_data.size
predicted_1y=[]
for i in range(size):
    #print(input)
    input_lstm=np.reshape(input[i:look_back+i],newshape=1*look_back)
    input_lstm=np.reshape(input_lstm, (1,look_back,1))
    #print(input_lstm)
    y=model.predict(input_lstm,verbose=0)
    #print(y)
    x=x=scaler.transform([r_data[i]])
    input=np.append(input,x)
    y=scaler.inverse_transform(y)
    predicted_1y.append(y[0])
    #print(predicted_y)
    #i=i+1

#print(predicted_y)

# %%
plt.figure(figsize=(12,5))
plt.plot(r_data, color = 'red', label = 'Real Test Data')
plt.plot(predicted_1y, color = 'blue', label = 'Predicted Test Data')
plt.title('one day ahead gold price prediction using GRU')
plt.xlabel('Time')
plt.ylabel('Gold price')
plt.legend()
plt.show()

# %%
import pickle
filename = 'GRU_oil.sav'
pickle.dump(model, open(filename, 'wb'))
